# %%
import requests
from bs4 import BeautifulSoup
import gensim
import json
from nltk.tokenize import word_tokenize
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: click in c:\users\igor\appdata\local\programs\python\python38\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in c:\users\igor\appdata\local\programs\python\python38\lib\site-packages (from nltk) (0.14.1)
# Collecting tqdm
#   Downloading tqdm-4.60.0-py2.py3-none-any.whl (75 kB)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the 'c:\users\igor\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# Collecting regex
#   Downloading regex-2021.4.4-cp38-cp38-win_amd64.whl (270 kB)
# Installing collected packages: tqdm, regex, nltk
# Successfully installed nltk-3.6.2 regex-2021.4.4 tqdm-4.60.0

# %%
pip install gensim
# Out:
#   File "<ipython-input-10-150b7668aad1>", line 2
#     pip install nltk
#         ^
# SyntaxError: invalid syntax

# %%
with open('C:\\Users\Igor\\PycharmProjects\\Web-service-for-discount-shoes\\Asos\\shoes.json') as f:
    file = json.load(f)

# %%
names = []
data = []
for key, value in file.items():
    names.append(key)
    data.append(value)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Igor\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
test = '''Nike Air Max 97 SE trainers in red and grey
Original price £149.95 Sale price £119.95 (-20%)£149.95 £119.95(-20%)
Or 3 payments of £39.98 with , or 4 of £29.98 with , always interest-free. COLOUR: Red Name a more iconic duo
Design inspired by Japanese bullet trains Low-profile design Pull tabs for easy entry Lace-up fastening  Padded tongue and cuff
Signature Nike branding  Foam midsole with Max Air cushioning Durable rubber outsole Waffle grip tread PRODUCT CODE
1975989 BRAND When it comes to innovative sportswear, no brand does it better than Nike. Discover the best-selling trainers in the game in our Nike at ASOS edit, from Air Force 1s to super-cushioned VaporMax styles. Browse techy T-shirts, shorts and joggers from Nike Training, Nike Running and Nike Football, as well as sports accessories like arm bands and fitness aids. Nike SB nails casual days with hoodies, sweatshirts and chinos, too.
LOOK AFTER ME Wipe clean with a damp cloth or sponge ABOUT ME Mesh, leather and faux-leather upper Sole: 80% Plastic, 20% Rubber.
'''

# %%
tagged_data = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in enumerate(data)]

# %%
max_epochs = 100
vec_size = 20
alpha = 0.025

model = Doc2Vec(size=vec_size,
                alpha=alpha, 
                min_alpha=0.00025,
                min_count=1,
                dm =1)
  
model.build_vocab(tagged_data)

for epoch in range(max_epochs):
    print('iteration {0}'.format(epoch))
    model.train(tagged_data,
                total_examples=model.corpus_count,
                epochs=model.iter)
    # decrease the learning rate
    model.alpha -= 0.0002
    # fix the learning rate, no decay
    model.min_alpha = model.alpha

model.save("d2v.model")
print("Model Saved")
# Out:
# c:\users\igor\appdata\local\programs\python\python38\lib\site-packages\gensim\models\doc2vec.py:319: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# iteration 0
# iteration 1
# <ipython-input-9-f2c2304d9f55>:17: DeprecationWarning: Call to deprecated `iter` (Attribute will be removed in 4.0.0, use self.epochs instead).
#   epochs=model.iter)
# iteration 2
# iteration 3
# iteration 4
# iteration 5
# iteration 6
# iteration 7
# iteration 8
# iteration 9
# iteration 10
# iteration 11
# iteration 12
# iteration 13
# iteration 14
# iteration 15
# iteration 16
# iteration 17
# iteration 18
# iteration 19
# iteration 20
# iteration 21
# iteration 22
# iteration 23
# iteration 24
# iteration 25
# iteration 26
# iteration 27
# iteration 28
# iteration 29
# iteration 30
# iteration 31
# iteration 32
# iteration 33
# iteration 34
# iteration 35
# iteration 36
# iteration 37
# iteration 38
# iteration 39
# iteration 40
# iteration 41
# iteration 42
# iteration 43
# iteration 44
# iteration 45
# iteration 46
# iteration 47
# iteration 48
# iteration 49
# iteration 50
# iteration 51
# iteration 52
# iteration 53
# iteration 54
# iteration 55
# iteration 56
# iteration 57
# iteration 58
# iteration 59
# iteration 60
# iteration 61
# iteration 62
# iteration 63
# iteration 64
# iteration 65
# iteration 66
# iteration 67
# iteration 68
# iteration 69
# iteration 70
# iteration 71
# iteration 72
# iteration 73
# iteration 74
# iteration 75
# iteration 76
# iteration 77
# iteration 78
# iteration 79
# iteration 80
# iteration 81
# iteration 82
# iteration 83
# iteration 84
# iteration 85
# iteration 86
# iteration 87
# iteration 88
# iteration 89
# iteration 90
# iteration 91
# iteration 92
# iteration 93
# iteration 94
# iteration 95
# iteration 96
# iteration 97
# iteration 98
# iteration 99
# Model Saved

# %%
test_data = word_tokenize(test.lower())
v1 = model.infer_vector(test_data)
print("V1_infer", v1)

# to find most similar doc using tags
similar_doc = model.docvecs.most_similar([v1])
print(similar_doc)
# Out:
# V1_infer [ 0.14749967 -0.03881999 -0.06410296 -0.1966219   0.1581726  -0.05341522
#  -0.00358301  0.06173364 -0.13953903  0.17008953  0.0660708   0.2594907
#   0.15200526  0.11127573 -0.23487039 -0.16951908  0.23529913  0.37724176
#  -0.22749104  0.4685451 ]
# [('9', 0.7973024249076843), ('24', 0.792247474193573), ('8', 0.7767677307128906), ('14', 0.7747820615768433), ('22', 0.7738237380981445), ('6', 0.7694768905639648), ('25', 0.7661781311035156), ('13', 0.7577733397483826), ('10', 0.7522437572479248), ('27', 0.7513531446456909)]

# %%
similar_doc = model.docvecs.most_similar('1')
print(similar_doc)
# Out:
# [('18', 0.9601889252662659), ('2', 0.9502037763595581), ('16', 0.948508083820343), ('19', 0.9453906416893005), ('21', 0.9445785880088806), ('17', 0.9283747673034668), ('4', 0.9253571033477783), ('0', 0.9235357046127319), ('20', 0.912948727607727), ('3', 0.8950543403625488)]

# %%
model.docvecs.most_similar(positive=['adidas'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b377d48bd605> in <module>
# ----> 1 model.docvecs.most_similar(positive=['adidas'])
#
# c:\users\igor\appdata\local\programs\python\python38\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, indexer)
#    1726             if isinstance(doc, ndarray):
#    1727                 mean.append(weight * doc)
# -> 1728             elif doc in self.doctags or doc < self.count:
#    1729                 mean.append(weight * self.vectors_docs_norm[self._int_index(doc, self.doctags, self.max_rawint)])
#    1730                 all_docs.add(self._int_index(doc, self.doctags, self.max_rawint))
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
model.wv.vocab
# Out:
# {'adidas': <gensim.models.keyedvectors.Vocab at 0x284ea7e6100>,
#  'originals': <gensim.models.keyedvectors.Vocab at 0x284ea7e6190>,
#  'lowertree': <gensim.models.keyedvectors.Vocab at 0x284ea7e61c0>,
#  'trainers': <gensim.models.keyedvectors.Vocab at 0x284ea7e6160>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x284ea7e6280>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x284ea7e62e0>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x284ea7e63a0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x284ea7e6400>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x284ea7e6460>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x284ea7e64c0>,
#  'asos': <gensim.models.keyedvectors.Vocab at 0x284ea7e6520>,
#  'brand': <gensim.models.keyedvectors.Vocab at 0x284ea7e6580>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x284ea7e65e0>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x284ea7e6640>,
#  'introduction': <gensim.models.keyedvectors.Vocab at 0x284ea7e6370>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x284ea7e66d0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x284ea7e6730>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x284ea7e6790>,
#  's': <gensim.models.keyedvectors.Vocab at 0x284ea7e67f0>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x284ea7e6850>,
#  '3-stripes': <gensim.models.keyedvectors.Vocab at 0x284ea7e68b0>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x284ea7e6940>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x284ea7e69d0>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x284ea7e6a30>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x284ea7e6a90>,
#  'track': <gensim.models.keyedvectors.Vocab at 0x284ea7e6af0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x284ea7e6b50>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x284ea7e6bb0>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x284ea7e6c10>,
#  'streetwear': <gensim.models.keyedvectors.Vocab at 0x284ea7e6970>,
#  'trends': <gensim.models.keyedvectors.Vocab at 0x284ea7e6ca0>,
#  'scroll': <gensim.models.keyedvectors.Vocab at 0x284ea7e6d00>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x284ea7e6d60>,
#  'edit': <gensim.models.keyedvectors.Vocab at 0x284ea7e6dc0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x284ea7e6e20>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x284ea7e6e80>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x284ea7e6ee0>,
#  'fix': <gensim.models.keyedvectors.Vocab at 0x284ea7e6f40>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x284ea7e6fa0>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x284ea7e6910>,
#  'iconic': <gensim.models.keyedvectors.Vocab at 0x284ea804040>,
#  'superstar': <gensim.models.keyedvectors.Vocab at 0x284ea8040a0>,
#  'stan': <gensim.models.keyedvectors.Vocab at 0x284ea804100>,
#  'smith': <gensim.models.keyedvectors.Vocab at 0x284ea804160>,
#  'gazelle': <gensim.models.keyedvectors.Vocab at 0x284ea8041c0>,
#  'continental': <gensim.models.keyedvectors.Vocab at 0x284ea804220>,
#  '80': <gensim.models.keyedvectors.Vocab at 0x284ea804280>,
#  'collections': <gensim.models.keyedvectors.Vocab at 0x284ea8042e0>,
#  'archive-inspired': <gensim.models.keyedvectors.Vocab at 0x284ea804340>,
#  'tracksuits': <gensim.models.keyedvectors.Vocab at 0x284ea8043a0>,
#  't-shirts': <gensim.models.keyedvectors.Vocab at 0x284ea804400>,
#  'sweatshirts': <gensim.models.keyedvectors.Vocab at 0x284ea804460>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x284ea8044c0>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x284ea804520>,
#  're': <gensim.models.keyedvectors.Vocab at 0x284ea804580>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x284ea8045e0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x284ea804640>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x284d9c86430>,
#  'kit': <gensim.models.keyedvectors.Vocab at 0x284ea8046d0>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x284ea804730>,
#  'cop': <gensim.models.keyedvectors.Vocab at 0x284ea804790>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x284ea8047f0>,
#  'sweat-wicking': <gensim.models.keyedvectors.Vocab at 0x284ea804850>,
#  'shorts': <gensim.models.keyedvectors.Vocab at 0x284ea8048b0>,
#  'vests': <gensim.models.keyedvectors.Vocab at 0x284ea804910>,
#  'compression': <gensim.models.keyedvectors.Vocab at 0x284ea804970>,
#  'tights': <gensim.models.keyedvectors.Vocab at 0x284ea8049d0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x284ea804a30>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x284ea804a90>,
#  'details': <gensim.models.keyedvectors.Vocab at 0x284ea804af0>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x284ea804b50>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x284ea804bb0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x284ea804c10>,
#  'rotation': <gensim.models.keyedvectors.Vocab at 0x284ea804c70>,
#  'low-profile': <gensim.models.keyedvectors.Vocab at 0x284ea804cd0>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x284ea804d30>,
#  'lace-up': <gensim.models.keyedvectors.Vocab at 0x284ea804d90>,
#  'fastening': <gensim.models.keyedvectors.Vocab at 0x284ea804df0>,
#  'padded': <gensim.models.keyedvectors.Vocab at 0x284ea804e50>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x284ea804eb0>,
#  'cuff': <gensim.models.keyedvectors.Vocab at 0x284ea804f10>,
#  'signature': <gensim.models.keyedvectors.Vocab at 0x284ea804f70>,
#  'branding': <gensim.models.keyedvectors.Vocab at 0x284ea804fd0>,
#  'eva': <gensim.models.keyedvectors.Vocab at 0x284ea805070>,
#  'midsole': <gensim.models.keyedvectors.Vocab at 0x284ea8050d0>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x284ea805130>,
#  'lightweight': <gensim.models.keyedvectors.Vocab at 0x284ea805190>,
#  'cushioning': <gensim.models.keyedvectors.Vocab at 0x284ea8051f0>,
#  'durable': <gensim.models.keyedvectors.Vocab at 0x284ea805250>,
#  'rubber': <gensim.models.keyedvectors.Vocab at 0x284ea8052b0>,
#  'outsole': <gensim.models.keyedvectors.Vocab at 0x284ea805310>,
#  'textured': <gensim.models.keyedvectors.Vocab at 0x284ea805370>,
#  'grip': <gensim.models.keyedvectors.Vocab at 0x284ea8053d0>,
#  'tread': <gensim.models.keyedvectors.Vocab at 0x284ea805430>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x284ea805490>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x284ea8054f0>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x284ea805550>,
#  'mesh': <gensim.models.keyedvectors.Vocab at 0x284ea8055b0>,
#  'faux-suede': <gensim.models.keyedvectors.Vocab at 0x284ea805610>,
#  'upper': <gensim.models.keyedvectors.Vocab at 0x284ea805670>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x284ea8056d0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x284ea805730>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x284ea805790>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x284ea8057f0>,
#  'polyester.': <gensim.models.keyedvectors.Vocab at 0x284ea805850>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x284ea8058b0>,
#  'nite': <gensim.models.keyedvectors.Vocab at 0x284ea805910>,
#  'jogger': <gensim.models.keyedvectors.Vocab at 0x284ea805970>,
#  'silver': <gensim.models.keyedvectors.Vocab at 0x284ea8059d0>,
#  'adidasswitch': <gensim.models.keyedvectors.Vocab at 0x284ea805a30>,
#  'rotationlow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea805a90>,
#  'designlace-up': <gensim.models.keyedvectors.Vocab at 0x284ea805af0>,
#  'boost': <gensim.models.keyedvectors.Vocab at 0x284ea805b50>,
#  'cushioningtpu': <gensim.models.keyedvectors.Vocab at 0x284ea805bb0>,
#  'heel': <gensim.models.keyedvectors.Vocab at 0x284ea805c10>,
#  'clip': <gensim.models.keyedvectors.Vocab at 0x284ea805c70>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x284ea805cd0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x284ea805d30>,
#  'secure': <gensim.models.keyedvectors.Vocab at 0x284ea805d90>,
#  'fitchunky': <gensim.models.keyedvectors.Vocab at 0x284ea805df0>,
#  'outsoletextured': <gensim.models.keyedvectors.Vocab at 0x284ea805e50>,
#  'textile': <gensim.models.keyedvectors.Vocab at 0x284ea805eb0>,
#  'uppermain': <gensim.models.keyedvectors.Vocab at 0x284ea805f10>,
#  'ultraboost': <gensim.models.keyedvectors.Vocab at 0x284ea805f70>,
#  's.rdy': <gensim.models.keyedvectors.Vocab at 0x284ea805fd0>,
#  'sky': <gensim.models.keyedvectors.Vocab at 0x284ea807070>,
#  'tint': <gensim.models.keyedvectors.Vocab at 0x284ea8070d0>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x284ea807130>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x284ea807190>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x284ea8071f0>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x284ea807250>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x284ea8072b0>,
#  'trainerslace-up': <gensim.models.keyedvectors.Vocab at 0x284ea807310>,
#  'responsive': <gensim.models.keyedvectors.Vocab at 0x284ea807370>,
#  'midsolestretchweb': <gensim.models.keyedvectors.Vocab at 0x284ea8073d0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x284ea807430>,
#  'rubbertextured': <gensim.models.keyedvectors.Vocab at 0x284ea807490>,
#  'primeknit': <gensim.models.keyedvectors.Vocab at 0x284ea8074f0>,
#  'upperknitted': <gensim.models.keyedvectors.Vocab at 0x284ea807550>,
#  'sock-like': <gensim.models.keyedvectors.Vocab at 0x284ea8075b0>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x284ea807610>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x284ea807670>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x284ea8076d0>,
#  'flexibility': <gensim.models.keyedvectors.Vocab at 0x284ea807730>,
#  'supportmade': <gensim.models.keyedvectors.Vocab at 0x284ea807790>,
#  'fewer': <gensim.models.keyedvectors.Vocab at 0x284ea8077f0>,
#  'materials': <gensim.models.keyedvectors.Vocab at 0x284ea807850>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x284ea8078b0>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x284ea807910>,
#  'wastesole': <gensim.models.keyedvectors.Vocab at 0x284ea807970>,
#  'textile.': <gensim.models.keyedvectors.Vocab at 0x284ea8079d0>,
#  'x_plr': <gensim.models.keyedvectors.Vocab at 0x284ea807a30>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x284ea807a90>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x284ea807af0>,
#  'tabs': <gensim.models.keyedvectors.Vocab at 0x284ea807b50>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x284ea807bb0>,
#  'entry': <gensim.models.keyedvectors.Vocab at 0x284ea807c10>,
#  'breathable': <gensim.models.keyedvectors.Vocab at 0x284ea807c70>,
#  'faux-leather': <gensim.models.keyedvectors.Vocab at 0x284ea807cd0>,
#  'overlaysupper': <gensim.models.keyedvectors.Vocab at 0x284ea807d30>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x284ea807d90>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x284ea807df0>,
#  'lining': <gensim.models.keyedvectors.Vocab at 0x284ea807e50>,
#  'sole': <gensim.models.keyedvectors.Vocab at 0x284ea807eb0>,
#  'materials.': <gensim.models.keyedvectors.Vocab at 0x284ea807f10>,
#  'sl': <gensim.models.keyedvectors.Vocab at 0x284ea807f70>,
#  '72': <gensim.models.keyedvectors.Vocab at 0x284ea807fd0>,
#  'adidasinspired': <gensim.models.keyedvectors.Vocab at 0x284ea809070>,
#  '1972': <gensim.models.keyedvectors.Vocab at 0x284ea8090d0>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x284ea809130>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x284ea809190>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x284ea8091f0>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x284ea809250>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x284ea8092b0>,
#  'trefoil': <gensim.models.keyedvectors.Vocab at 0x284ea809310>,
#  'logolow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea809370>,
#  'perforated': <gensim.models.keyedvectors.Vocab at 0x284ea8093d0>,
#  'breathabilitysignature': <gensim.models.keyedvectors.Vocab at 0x284ea809430>,
#  'cushioningdurable': <gensim.models.keyedvectors.Vocab at 0x284ea809490>,
#  'suede': <gensim.models.keyedvectors.Vocab at 0x284ea8094f0>,
#  'nylon': <gensim.models.keyedvectors.Vocab at 0x284ea809550>,
#  'upperortholite': <gensim.models.keyedvectors.Vocab at 0x284ea8095b0>,
#  'insole': <gensim.models.keyedvectors.Vocab at 0x284ea809610>,
#  'wicks': <gensim.models.keyedvectors.Vocab at 0x284ea809670>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x284ea8096d0>,
#  'sweat': <gensim.models.keyedvectors.Vocab at 0x284ea809730>,
#  'cushioningupper': <gensim.models.keyedvectors.Vocab at 0x284ea809790>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x284ea8097f0>,
#  'leather': <gensim.models.keyedvectors.Vocab at 0x284ea809850>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x284ea8098b0>,
#  'shopping': <gensim.models.keyedvectors.Vocab at 0x284ea809910>,
#  'clothes': <gensim.models.keyedvectors.Vocab at 0x284ea809970>,
#  'fashionnonenone': <gensim.models.keyedvectors.Vocab at 0x284ea8099d0>,
#  'supercourt': <gensim.models.keyedvectors.Vocab at 0x284ea809a30>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x284ea809a90>,
#  'royal': <gensim.models.keyedvectors.Vocab at 0x284ea809af0>,
#  'blue': <gensim.models.keyedvectors.Vocab at 0x284ea809b50>,
#  'uppersole': <gensim.models.keyedvectors.Vocab at 0x284ea809bb0>,
#  'polyurethane.': <gensim.models.keyedvectors.Vocab at 0x284ea809c10>,
#  'campus': <gensim.models.keyedvectors.Vocab at 0x284ea809c70>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x284ea809cd0>,
#  'adidasif': <gensim.models.keyedvectors.Vocab at 0x284ea809d30>,
#  'trainerslow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea809d90>,
#  'fasteningpadded': <gensim.models.keyedvectors.Vocab at 0x284ea809df0>,
#  'cuffsignature': <gensim.models.keyedvectors.Vocab at 0x284ea809e50>,
#  'soft': <gensim.models.keyedvectors.Vocab at 0x284ea809eb0>,
#  'upperlining': <gensim.models.keyedvectors.Vocab at 0x284ea809f10>,
#  'grey': <gensim.models.keyedvectors.Vocab at 0x284ea809f70>,
#  'collegiate': <gensim.models.keyedvectors.Vocab at 0x284ea809fd0>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x284ea80a070>,
#  'vegan': <gensim.models.keyedvectors.Vocab at 0x284ea80a0d0>,
#  'contrast': <gensim.models.keyedvectors.Vocab at 0x284ea80a130>,
#  'panelsdurable': <gensim.models.keyedvectors.Vocab at 0x284ea80a190>,
#  'smooth': <gensim.models.keyedvectors.Vocab at 0x284ea80a1f0>,
#  'court': <gensim.models.keyedvectors.Vocab at 0x284ea80a250>,
#  'gold-tone': <gensim.models.keyedvectors.Vocab at 0x284ea80a2b0>,
#  'chunky': <gensim.models.keyedvectors.Vocab at 0x284ea80a310>,
#  'matte': <gensim.models.keyedvectors.Vocab at 0x284ea80a370>,
#  'leather.': <gensim.models.keyedvectors.Vocab at 0x284ea80a3d0>,
#  'rivalry': <gensim.models.keyedvectors.Vocab at 0x284ea80a430>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x284ea80a490>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x284ea80a4f0>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x284ea80a550>,
#  'cleanlow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea80a5b0>,
#  'brandingperforated': <gensim.models.keyedvectors.Vocab at 0x284ea80a610>,
#  'toe': <gensim.models.keyedvectors.Vocab at 0x284ea80a670>,
#  'breathabilitydurable': <gensim.models.keyedvectors.Vocab at 0x284ea80a6d0>,
#  'uppersoft': <gensim.models.keyedvectors.Vocab at 0x284ea80a730>,
#  'lininglining': <gensim.models.keyedvectors.Vocab at 0x284ea80a790>,
#  'zx': <gensim.models.keyedvectors.Vocab at 0x284ea80a7f0>,
#  'flux': <gensim.models.keyedvectors.Vocab at 0x284ea80a850>,
#  'originalslace-up': <gensim.models.keyedvectors.Vocab at 0x284ea80a8b0>,
#  'cuffsbreathable': <gensim.models.keyedvectors.Vocab at 0x284ea80a910>,
#  'ortholite®': <gensim.models.keyedvectors.Vocab at 0x284ea80a970>,
#  'sockliner': <gensim.models.keyedvectors.Vocab at 0x284ea80a9d0>,
#  'contains': <gensim.models.keyedvectors.Vocab at 0x284ea80aa30>,
#  'anti-bacterial': <gensim.models.keyedvectors.Vocab at 0x284ea80aa90>,
#  'properties': <gensim.models.keyedvectors.Vocab at 0x284ea80aaf0>,
#  'branded': <gensim.models.keyedvectors.Vocab at 0x284ea80ab50>,
#  'sidesmoulded': <gensim.models.keyedvectors.Vocab at 0x284ea80abb0>,
#  'cage': <gensim.models.keyedvectors.Vocab at 0x284ea80ac10>,
#  'supportcompression': <gensim.models.keyedvectors.Vocab at 0x284ea80ac70>,
#  'cushioningmoulded': <gensim.models.keyedvectors.Vocab at 0x284ea80acd0>,
#  'upperkeeps': <gensim.models.keyedvectors.Vocab at 0x284ea80ad30>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x284ea80ad90>,
#  'fresher': <gensim.models.keyedvectors.Vocab at 0x284ea80adf0>,
#  'longerlining': <gensim.models.keyedvectors.Vocab at 0x284ea80ae50>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x284ea5d8280>,
#  'classics': <gensim.models.keyedvectors.Vocab at 0x284ea80aeb0>,
#  'sustainable': <gensim.models.keyedvectors.Vocab at 0x284ea80af10>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x284ea80af70>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x284ea80afd0>,
#  'responsible': <gensim.models.keyedvectors.Vocab at 0x284ea80c070>,
#  'moulded': <gensim.models.keyedvectors.Vocab at 0x284ea80c0d0>,
#  'uppermade': <gensim.models.keyedvectors.Vocab at 0x284ea80c130>,
#  'recycled': <gensim.models.keyedvectors.Vocab at 0x284ea80c190>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x284ea80c1f0>,
#  'circular': <gensim.models.keyedvectors.Vocab at 0x284ea80c250>,
#  'approachwe': <gensim.models.keyedvectors.Vocab at 0x284ea80c2b0>,
#  've': <gensim.models.keyedvectors.Vocab at 0x284ea80c310>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x284ea80c370>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x284ea80c3d0>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x284ea80c430>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x284ea80c490>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x284ea80c4f0>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x284ea80c550>,
#  'newlining': <gensim.models.keyedvectors.Vocab at 0x284ea80c5b0>,
#  'ben': <gensim.models.keyedvectors.Vocab at 0x284ea80c610>,
#  'sherman': <gensim.models.keyedvectors.Vocab at 0x284ea80c670>,
#  'shoe': <gensim.models.keyedvectors.Vocab at 0x284ea80c6d0>,
#  'shine': <gensim.models.keyedvectors.Vocab at 0x284ea80c730>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x284ea80c790>,
#  'adopted': <gensim.models.keyedvectors.Vocab at 0x284ea80c7f0>,
#  'mod': <gensim.models.keyedvectors.Vocab at 0x284ea80c850>,
#  'movement': <gensim.models.keyedvectors.Vocab at 0x284ea80c8b0>,
#  '1960s': <gensim.models.keyedvectors.Vocab at 0x284ea80c910>,
#  'channel': <gensim.models.keyedvectors.Vocab at 0x284ea80c970>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x284ea80c9d0>,
#  'roots': <gensim.models.keyedvectors.Vocab at 0x284ea80ca30>,
#  'contemporary': <gensim.models.keyedvectors.Vocab at 0x284ea80ca90>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x284ea80caf0>,
#  'menswear': <gensim.models.keyedvectors.Vocab at 0x284ea80cb50>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x284ea80cbb0>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x284ea80cc10>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x284ea80cc70>,
#  'shirts': <gensim.models.keyedvectors.Vocab at 0x284ea80ccd0>,
#  'polos': <gensim.models.keyedvectors.Vocab at 0x284ea80cd30>,
#  'print': <gensim.models.keyedvectors.Vocab at 0x284ea80cd90>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x284ea80cdf0>,
#  'shermangift': <gensim.models.keyedvectors.Vocab at 0x284ea80ce50>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x284ea80ceb0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x284ea80cf10>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x284ea80cf70>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x284ea80cfd0>,
#  'carry': <gensim.models.keyedvectors.Vocab at 0x284ea80f070>,
#  'caseincludes': <gensim.models.keyedvectors.Vocab at 0x284ea80f0d0>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x284ea80f130>,
#  'brushes': <gensim.models.keyedvectors.Vocab at 0x284ea80f190>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x284ea80f1f0>,
#  'polishes': <gensim.models.keyedvectors.Vocab at 0x284ea80f250>,
#  'cloth': <gensim.models.keyedvectors.Vocab at 0x284ea80f2b0>,
#  'elastic': <gensim.models.keyedvectors.Vocab at 0x284ea80f310>,
#  'loops': <gensim.models.keyedvectors.Vocab at 0x284ea80f370>,
#  'storagezip': <gensim.models.keyedvectors.Vocab at 0x284ea80f3d0>,
#  'tightly': <gensim.models.keyedvectors.Vocab at 0x284ea80f430>,
#  'woven': <gensim.models.keyedvectors.Vocab at 0x284ea80f490>,
#  'fabricit': <gensim.models.keyedvectors.Vocab at 0x284ea80f4f0>,
#  'versatile': <gensim.models.keyedvectors.Vocab at 0x284ea80f550>,
#  'dependable': <gensim.models.keyedvectors.Vocab at 0x284ea80f5b0>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x284ea80f610>,
#  'toms': <gensim.models.keyedvectors.Vocab at 0x284ea80f670>,
#  'trvl': <gensim.models.keyedvectors.Vocab at 0x284ea80f6d0>,
#  'lite': <gensim.models.keyedvectors.Vocab at 0x284ea80f730>,
#  'lace': <gensim.models.keyedvectors.Vocab at 0x284ea80f790>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x284ea80f7f0>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x284ea80f850>,
#  'launch': <gensim.models.keyedvectors.Vocab at 0x284ea80f8b0>,
#  '2006': <gensim.models.keyedvectors.Vocab at 0x284ea80f910>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x284ea80f970>,
#  'gifted': <gensim.models.keyedvectors.Vocab at 0x284ea80f9d0>,
#  'millions': <gensim.models.keyedvectors.Vocab at 0x284ea80fa30>,
#  'pairs': <gensim.models.keyedvectors.Vocab at 0x284ea80fa90>,
#  'shoes': <gensim.models.keyedvectors.Vocab at 0x284ea80faf0>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x284ea80fb50>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x284ea80fbb0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x284ea80fc10>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x284ea80fc70>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x284ea80fcd0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x284ea80fd30>,
#  'committed': <gensim.models.keyedvectors.Vocab at 0x284ea80fd90>,
#  'donate': <gensim.models.keyedvectors.Vocab at 0x284ea80fdf0>,
#  '£1': <gensim.models.keyedvectors.Vocab at 0x284ea80fe50>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x284ea80feb0>,
#  '£3': <gensim.models.keyedvectors.Vocab at 0x284ea80ff10>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x284ea80ff70>,
#  'organisations': <gensim.models.keyedvectors.Vocab at 0x284ea80ffd0>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x284ea810070>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x284ea8100d0>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x284ea810130>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x284ea810190>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x284ea8101f0>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x284ea810250>,
#  'opportunity': <gensim.models.keyedvectors.Vocab at 0x284ea8102b0>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x284ea810310>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x284ea810370>,
#  'canvas': <gensim.models.keyedvectors.Vocab at 0x284ea8103d0>,
#  'boat': <gensim.models.keyedvectors.Vocab at 0x284ea810430>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x284ea810490>,
#  'forgetting': <gensim.models.keyedvectors.Vocab at 0x284ea8104f0>,
#  'espadrilles': <gensim.models.keyedvectors.Vocab at 0x284ea810550>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x284ea8105b0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x284ea810610>,
#  'designpull': <gensim.models.keyedvectors.Vocab at 0x284ea810670>,
#  'tab': <gensim.models.keyedvectors.Vocab at 0x284ea8106d0>,
#  'entrylace-up': <gensim.models.keyedvectors.Vocab at 0x284ea810730>,
#  'brave': <gensim.models.keyedvectors.Vocab at 0x284ea810790>,
#  'soul': <gensim.models.keyedvectors.Vocab at 0x284ea8107f0>,
#  'faux': <gensim.models.keyedvectors.Vocab at 0x284ea810850>,
#  'loafers': <gensim.models.keyedvectors.Vocab at 0x284ea8108b0>,
#  'beige': <gensim.models.keyedvectors.Vocab at 0x284ea810910>,
#  'asosnone': <gensim.models.keyedvectors.Vocab at 0x284ea810970>,
#  'reasons': <gensim.models.keyedvectors.Vocab at 0x284ea8109d0>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x284ea810a30>,
#  'bag': <gensim.models.keyedvectors.Vocab at 0x284ea810a90>,
#  'slip-on': <gensim.models.keyedvectors.Vocab at 0x284ea810af0>,
#  'tassel': <gensim.models.keyedvectors.Vocab at 0x284ea810b50>,
#  'detailwoven': <gensim.models.keyedvectors.Vocab at 0x284ea810bb0>,
#  'inserts': <gensim.models.keyedvectors.Vocab at 0x284ea810c10>,
#  'apron': <gensim.models.keyedvectors.Vocab at 0x284ea810c70>,
#  'flat': <gensim.models.keyedvectors.Vocab at 0x284ea810cd0>,
#  'polyurethane': <gensim.models.keyedvectors.Vocab at 0x284ea810d30>,
#  'polyvinylchloride': <gensim.models.keyedvectors.Vocab at 0x284ea810d90>,
#  'utility': <gensim.models.keyedvectors.Vocab at 0x284ea810df0>,
#  'sliders': <gensim.models.keyedvectors.Vocab at 0x284ea810e50>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x284ea810eb0>,
#  'feetslip-on': <gensim.models.keyedvectors.Vocab at 0x284ea810f10>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x284ea810f70>,
#  'strapbuckle': <gensim.models.keyedvectors.Vocab at 0x284ea810fd0>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x284ea812070>,
#  'footbed': <gensim.models.keyedvectors.Vocab at 0x284ea8120d0>,
#  'plain-woven': <gensim.models.keyedvectors.Vocab at 0x284ea812130>,
#  'polyester': <gensim.models.keyedvectors.Vocab at 0x284ea812190>,
#  'truffle': <gensim.models.keyedvectors.Vocab at 0x284ea8121f0>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x284ea812250>,
#  'flip': <gensim.models.keyedvectors.Vocab at 0x284ea8122b0>,
#  'flops': <gensim.models.keyedvectors.Vocab at 0x284ea812310>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x284ea812370>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x284ea8123d0>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x284ea812430>,
#  'effectsv-shaped': <gensim.models.keyedvectors.Vocab at 0x284ea812490>,
#  'straps': <gensim.models.keyedvectors.Vocab at 0x284ea8124f0>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x284ea812550>,
#  'slip-resistant': <gensim.models.keyedvectors.Vocab at 0x284ea8125b0>,
#  'rubberised': <gensim.models.keyedvectors.Vocab at 0x284ea812610>,
#  'ethylene': <gensim.models.keyedvectors.Vocab at 0x284ea812670>,
#  'vinyl': <gensim.models.keyedvectors.Vocab at 0x284ea8126d0>,
#  'acetate': <gensim.models.keyedvectors.Vocab at 0x284ea812730>,
#  'polyvinylchloride.': <gensim.models.keyedvectors.Vocab at 0x284ea812790>,
#  'penguin': <gensim.models.keyedvectors.Vocab at 0x284ea8127f0>,
#  'buckle': <gensim.models.keyedvectors.Vocab at 0x284ea812850>,
#  'sandals': <gensim.models.keyedvectors.Vocab at 0x284ea8128b0>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x284ea812910>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x284ea812970>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x284ea8129d0>,
#  'golf': <gensim.models.keyedvectors.Vocab at 0x284ea812a30>,
#  'shirt': <gensim.models.keyedvectors.Vocab at 0x284ea812a90>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x284ea812af0>,
#  '1955': <gensim.models.keyedvectors.Vocab at 0x284ea812b50>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x284ea812bb0>,
#  'synonymous': <gensim.models.keyedvectors.Vocab at 0x284ea812c10>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x284ea812c70>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x284ea812cd0>,
#  'talked-about': <gensim.models.keyedvectors.Vocab at 0x284ea812d30>,
#  'stars': <gensim.models.keyedvectors.Vocab at 0x284ea812d90>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x284ea812df0>,
#  'frank': <gensim.models.keyedvectors.Vocab at 0x284ea812e50>,
#  'sinatra': <gensim.models.keyedvectors.Vocab at 0x284ea812eb0>,
#  'dean': <gensim.models.keyedvectors.Vocab at 0x284ea812f10>,
#  'martin': <gensim.models.keyedvectors.Vocab at 0x284ea812f70>,
#  'clint': <gensim.models.keyedvectors.Vocab at 0x284ea812fd0>,
#  'eastwood': <gensim.models.keyedvectors.Vocab at 0x284ea815070>,
#  'nod': <gensim.models.keyedvectors.Vocab at 0x284ea8150d0>,
#  'americana': <gensim.models.keyedvectors.Vocab at 0x284ea815130>,
#  'designs': <gensim.models.keyedvectors.Vocab at 0x284ea815190>,
#  'jackets': <gensim.models.keyedvectors.Vocab at 0x284ea8151f0>,
#  'accessories': <gensim.models.keyedvectors.Vocab at 0x284ea815250>,
#  'alongside': <gensim.models.keyedvectors.Vocab at 0x284ea8152b0>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x284ea815310>,
#  'polo': <gensim.models.keyedvectors.Vocab at 0x284ea815370>,
#  'open-toe': <gensim.models.keyedvectors.Vocab at 0x284ea8153d0>,
#  'season': <gensim.models.keyedvectors.Vocab at 0x284ea815430>,
#  'styledouble': <gensim.models.keyedvectors.Vocab at 0x284ea815490>,
#  'pin-buckle': <gensim.models.keyedvectors.Vocab at 0x284ea8154f0>,
#  'leather-mix': <gensim.models.keyedvectors.Vocab at 0x284ea815550>,
#  'footbedupper': <gensim.models.keyedvectors.Vocab at 0x284ea8155b0>,
#  'logo': <gensim.models.keyedvectors.Vocab at 0x284ea815610>,
#  'poolside': <gensim.models.keyedvectors.Vocab at 0x284ea815670>,
#  'vibesslip-on': <gensim.models.keyedvectors.Vocab at 0x284ea8156d0>,
#  'stylewide': <gensim.models.keyedvectors.Vocab at 0x284ea815730>,
#  'strapdebossed': <gensim.models.keyedvectors.Vocab at 0x284ea815790>,
#  'detailopen': <gensim.models.keyedvectors.Vocab at 0x284ea8157f0>,
#  'toemoulded': <gensim.models.keyedvectors.Vocab at 0x284ea815850>,
#  'calvin': <gensim.models.keyedvectors.Vocab at 0x284ea8158b0>,
#  'klein': <gensim.models.keyedvectors.Vocab at 0x284ea815910>,
#  'antal': <gensim.models.keyedvectors.Vocab at 0x284ea815970>,
#  'plimsolls': <gensim.models.keyedvectors.Vocab at 0x284ea8159d0>,
#  'underwear': <gensim.models.keyedvectors.Vocab at 0x284ea815a30>,
#  'authority': <gensim.models.keyedvectors.Vocab at 0x284ea815a90>,
#  'all-round': <gensim.models.keyedvectors.Vocab at 0x284ea815af0>,
#  'fashion': <gensim.models.keyedvectors.Vocab at 0x284ea815b50>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x284ea815bb0>,
#  'puts': <gensim.models.keyedvectors.Vocab at 0x284ea815c10>,
#  'designer': <gensim.models.keyedvectors.Vocab at 0x284ea815c70>,
#  'stamp': <gensim.models.keyedvectors.Vocab at 0x284ea815cd0>,
#  'casual-cool': <gensim.models.keyedvectors.Vocab at 0x284ea815d30>,
#  'staples': <gensim.models.keyedvectors.Vocab at 0x284ea815d90>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x284ea815df0>,
#  'waistbands': <gensim.models.keyedvectors.Vocab at 0x284ea815e50>,
#  'ck': <gensim.models.keyedvectors.Vocab at 0x284ea815eb0>,
#  'serves': <gensim.models.keyedvectors.Vocab at 0x284ea815f10>,
#  'instant': <gensim.models.keyedvectors.Vocab at 0x284ea815f70>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x284ea815fd0>,
#  'refresh': <gensim.models.keyedvectors.Vocab at 0x284ea816070>,
#  'basics': <gensim.models.keyedvectors.Vocab at 0x284ea8160d0>,
#  'jeans': <gensim.models.keyedvectors.Vocab at 0x284ea816130>,
#  'loungewear': <gensim.models.keyedvectors.Vocab at 0x284ea816190>,
#  'tailored': <gensim.models.keyedvectors.Vocab at 0x284ea8161f0>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x284ea816250>,
#  'trousers': <gensim.models.keyedvectors.Vocab at 0x284ea8162b0>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x284ea816310>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x284ea816370>,
#  't': <gensim.models.keyedvectors.Vocab at 0x284ea8163d0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x284ea816430>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x284ea816490>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x284ea8164f0>,
#  'pair': <gensim.models.keyedvectors.Vocab at 0x284ea816550>,
#  'briefs': <gensim.models.keyedvectors.Vocab at 0x284ea8165b0>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x284ea816610>,
#  'jeanstwo': <gensim.models.keyedvectors.Vocab at 0x284ea816670>,
#  'cotton': <gensim.models.keyedvectors.Vocab at 0x284ea8166d0>,
#  'cotton.': <gensim.models.keyedvectors.Vocab at 0x284ea816730>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x284ea816790>,
#  'patent': <gensim.models.keyedvectors.Vocab at 0x284ea8167f0>,
#  'loafer': <gensim.models.keyedvectors.Vocab at 0x284ea816850>,
#  'double': <gensim.models.keyedvectors.Vocab at 0x284ea8168b0>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x284ea816910>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x284ea816970>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x284ea8169d0>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x284ea816a30>,
#  'go-to': <gensim.models.keyedvectors.Vocab at 0x284ea816a90>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x284ea816af0>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x284ea816b50>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x284ea816bb0>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x284ea816c10>,
#  'exclusive': <gensim.models.keyedvectors.Vocab at 0x284ea816c70>,
#  'universal': <gensim.models.keyedvectors.Vocab at 0x284ea816cd0>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x284ea816d30>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x284ea816d90>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x284ea816df0>,
#  'tall': <gensim.models.keyedvectors.Vocab at 0x284ea816e50>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x284ea816eb0>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x284ea816f10>,
#  'styled': <gensim.models.keyedvectors.Vocab at 0x284ea816f70>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x284ea816fd0>,
#  'treadwide': <gensim.models.keyedvectors.Vocab at 0x284ea818070>,
#  'glossy': <gensim.models.keyedvectors.Vocab at 0x284ea8180d0>,
#  'heeled': <gensim.models.keyedvectors.Vocab at 0x284ea818130>,
#  'chelsea': <gensim.models.keyedvectors.Vocab at 0x284ea818190>,
#  'boots': <gensim.models.keyedvectors.Vocab at 0x284ea8181f0>,
#  'pointed': <gensim.models.keyedvectors.Vocab at 0x284ea818250>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x284ea8182b0>,
#  'strap': <gensim.models.keyedvectors.Vocab at 0x284ea818310>,
#  'zip-side': <gensim.models.keyedvectors.Vocab at 0x284ea818370>,
#  'fasteningstrap': <gensim.models.keyedvectors.Vocab at 0x284ea8183d0>,
#  'detailssilver-tone': <gensim.models.keyedvectors.Vocab at 0x284ea818430>,
#  'chains': <gensim.models.keyedvectors.Vocab at 0x284ea818490>,
#  'studs': <gensim.models.keyedvectors.Vocab at 0x284ea8184f0>,
#  'toeblock': <gensim.models.keyedvectors.Vocab at 0x284ea818550>,
#  'topman': <gensim.models.keyedvectors.Vocab at 0x284ea8185b0>,
#  'cuban': <gensim.models.keyedvectors.Vocab at 0x284ea818610>,
#  'tan': <gensim.models.keyedvectors.Vocab at 0x284ea818670>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x284ea8186d0>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x284ea818730>,
#  'dresses': <gensim.models.keyedvectors.Vocab at 0x284ea818790>,
#  'occasion': <gensim.models.keyedvectors.Vocab at 0x284ea8187f0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x284ea818850>,
#  'calendar': <gensim.models.keyedvectors.Vocab at 0x284ea8188b0>,
#  'clothing': <gensim.models.keyedvectors.Vocab at 0x284ea818910>,
#  'slot': <gensim.models.keyedvectors.Vocab at 0x284ea818970>,
#  'denim': <gensim.models.keyedvectors.Vocab at 0x284ea8189d0>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x284ea818a30>,
#  'tees': <gensim.models.keyedvectors.Vocab at 0x284ea818a90>,
#  'casualwear': <gensim.models.keyedvectors.Vocab at 0x284ea818af0>,
#  'opt': <gensim.models.keyedvectors.Vocab at 0x284ea818b50>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x284ea818bb0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x284ea818c10>,
#  't-shirt': <gensim.models.keyedvectors.Vocab at 0x284ea818c70>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x284ea818cd0>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x284ea818d30>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x284ea818d90>,
#  'entryzip-side': <gensim.models.keyedvectors.Vocab at 0x284ea818df0>,
#  'round': <gensim.models.keyedvectors.Vocab at 0x284ea818e50>,
#  'toecontrast': <gensim.models.keyedvectors.Vocab at 0x284ea818eb0>,
#  'soletextured': <gensim.models.keyedvectors.Vocab at 0x284ea818f10>,
#  'suede.': <gensim.models.keyedvectors.Vocab at 0x284ea818f70>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x284ea818fd0>,
#  'hudson': <gensim.models.keyedvectors.Vocab at 0x284ea81b070>,
#  'battle': <gensim.models.keyedvectors.Vocab at 0x284ea81b0d0>,
#  'burgundy': <gensim.models.keyedvectors.Vocab at 0x284ea81b130>,
#  'launched': <gensim.models.keyedvectors.Vocab at 0x284ea81b190>,
#  '2004': <gensim.models.keyedvectors.Vocab at 0x284ea81b1f0>,
#  'footwear': <gensim.models.keyedvectors.Vocab at 0x284ea81b250>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x284ea81b2b0>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x284ea81b310>,
#  'reworks': <gensim.models.keyedvectors.Vocab at 0x284ea81b370>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x284ea81b3d0>,
#  'in-house': <gensim.models.keyedvectors.Vocab at 0x284ea81b430>,
#  'referencing': <gensim.models.keyedvectors.Vocab at 0x284ea81b490>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x284ea81b4f0>,
#  'youth': <gensim.models.keyedvectors.Vocab at 0x284ea81b550>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x284ea81b5b0>,
#  'influences': <gensim.models.keyedvectors.Vocab at 0x284ea81b610>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x284ea81b670>,
#  'military': <gensim.models.keyedvectors.Vocab at 0x284ea81b6d0>,
#  'styles': <gensim.models.keyedvectors.Vocab at 0x284ea81b730>,
#  'brogues': <gensim.models.keyedvectors.Vocab at 0x284ea81b790>,
#  'toechunky': <gensim.models.keyedvectors.Vocab at 0x284ea81b7f0>,
#  'aldo': <gensim.models.keyedvectors.Vocab at 0x284ea81b850>,
#  'mynytho': <gensim.models.keyedvectors.Vocab at 0x284ea81b8b0>,
#  'casual': <gensim.models.keyedvectors.Vocab at 0x284ea81b910>,
#  'thong': <gensim.models.keyedvectors.Vocab at 0x284ea81b970>,
#  'brown': <gensim.models.keyedvectors.Vocab at 0x284ea81b9d0>,
#  'bensadoun': <gensim.models.keyedvectors.Vocab at 0x284ea81ba30>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x284ea81ba90>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x284ea81baf0>,
#  'namesake': <gensim.models.keyedvectors.Vocab at 0x284ea81bb50>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x284ea81bbb0>,
#  'montreal': <gensim.models.keyedvectors.Vocab at 0x284ea81bc10>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x284ea81bc70>,
#  'global': <gensim.models.keyedvectors.Vocab at 0x284ea81bcd0>,
#  'expansion': <gensim.models.keyedvectors.Vocab at 0x284ea81bd30>,
#  'quickly': <gensim.models.keyedvectors.Vocab at 0x284ea81bd90>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x284ea81bdf0>,
#  'conscience': <gensim.models.keyedvectors.Vocab at 0x284ea81be50>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x284ea81beb0>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x284ea81bf10>,
#  'supporting': <gensim.models.keyedvectors.Vocab at 0x284ea81bf70>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x284ea81bfd0>,
#  'charities': <gensim.models.keyedvectors.Vocab at 0x284ea81c070>,
#  'communities': <gensim.models.keyedvectors.Vocab at 0x284ea81c0d0>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x284ea81c130>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x284ea81c190>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x284ea81c1f0>,
#  'adapting': <gensim.models.keyedvectors.Vocab at 0x284ea81c250>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x284ea81c2b0>,
#  'changing': <gensim.models.keyedvectors.Vocab at 0x284ea81c310>,
#  'desires': <gensim.models.keyedvectors.Vocab at 0x284ea81c370>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x284ea81c3d0>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x284ea81c430>,
#  'worldwide': <gensim.models.keyedvectors.Vocab at 0x284ea81c490>,
#  'ensure': <gensim.models.keyedvectors.Vocab at 0x284ea81c4f0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x284ea81c550>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x284ea81c5b0>,
#  'perfectly': <gensim.models.keyedvectors.Vocab at 0x284ea81c610>,
#  'edited': <gensim.models.keyedvectors.Vocab at 0x284ea81c670>,
#  'cutting-edge': <gensim.models.keyedvectors.Vocab at 0x284ea81c6d0>,
#  'wearable': <gensim.models.keyedvectors.Vocab at 0x284ea81c730>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x284ea81c790>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x284ea81c7f0>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x284ea81c850>,
#  'v-shaped': <gensim.models.keyedvectors.Vocab at 0x284ea81c8b0>,
#  'straptoe': <gensim.models.keyedvectors.Vocab at 0x284ea81c910>,
#  '84': <gensim.models.keyedvectors.Vocab at 0x284ea81c970>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x284ea81c9d0>,
#  'elastane': <gensim.models.keyedvectors.Vocab at 0x284ea81ca30>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x284ea81ca90>,
#  'khaki': <gensim.models.keyedvectors.Vocab at 0x284ea81caf0>,
#  'elasticated': <gensim.models.keyedvectors.Vocab at 0x284ea81cb50>,
#  'rope': <gensim.models.keyedvectors.Vocab at 0x284ea81cbb0>,
#  'canvas.': <gensim.models.keyedvectors.Vocab at 0x284ea81cc10>,
#  'snaffle': <gensim.models.keyedvectors.Vocab at 0x284ea81cc70>,
#  'bar': <gensim.models.keyedvectors.Vocab at 0x284ea81ccd0>,
#  'stripe': <gensim.models.keyedvectors.Vocab at 0x284ea81cd30>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x284ea81cd90>,
#  'thingslip-on': <gensim.models.keyedvectors.Vocab at 0x284ea81cdf0>,
#  'stylelogo': <gensim.models.keyedvectors.Vocab at 0x284ea81ce50>,
#  'heelcontrast': <gensim.models.keyedvectors.Vocab at 0x284ea81ceb0>,
#  'trimsnaffle': <gensim.models.keyedvectors.Vocab at 0x284ea81cf10>,
#  'frontapron': <gensim.models.keyedvectors.Vocab at 0x284ea81cf70>,
#  'toerubber': <gensim.models.keyedvectors.Vocab at 0x284ea81cfd0>,
#  'slip': <gensim.models.keyedvectors.Vocab at 0x284ea81e070>,
#  'stylelow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea81e0d0>,
#  'insertschunky': <gensim.models.keyedvectors.Vocab at 0x284ea81e130>,
#  'wide-cut': <gensim.models.keyedvectors.Vocab at 0x284ea81e190>,
#  'fastenings': <gensim.models.keyedvectors.Vocab at 0x284ea81e1f0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x284ea81e250>,
#  'upperupper': <gensim.models.keyedvectors.Vocab at 0x284ea81e2b0>,
#  'aurelio': <gensim.models.keyedvectors.Vocab at 0x284ea81e310>,
#  'twill': <gensim.models.keyedvectors.Vocab at 0x284ea81e370>,
#  'mix': <gensim.models.keyedvectors.Vocab at 0x284ea81e3d0>,
#  'western': <gensim.models.keyedvectors.Vocab at 0x284ea81e430>,
#  'pink': <gensim.models.keyedvectors.Vocab at 0x284ea81e490>,
#  'metal': <gensim.models.keyedvectors.Vocab at 0x284ea81e4f0>,
#  'hardware': <gensim.models.keyedvectors.Vocab at 0x284ea81e550>,
#  'backpull-on': <gensim.models.keyedvectors.Vocab at 0x284ea81e5b0>,
#  'styleelasticated': <gensim.models.keyedvectors.Vocab at 0x284ea81e610>,
#  'insertssquare': <gensim.models.keyedvectors.Vocab at 0x284ea81e670>,
#  'metallic': <gensim.models.keyedvectors.Vocab at 0x284ea81e6d0>,
#  'capslim': <gensim.models.keyedvectors.Vocab at 0x284ea81e730>,
#  'solelow': <gensim.models.keyedvectors.Vocab at 0x284ea81e790>,
#  'atol': <gensim.models.keyedvectors.Vocab at 0x284ea81e7f0>,
#  'brogue': <gensim.models.keyedvectors.Vocab at 0x284ea81e850>,
#  'detailing': <gensim.models.keyedvectors.Vocab at 0x284ea81e8b0>,
#  'fasteningtassel': <gensim.models.keyedvectors.Vocab at 0x284ea81e910>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x284ea81e970>,
#  'slim': <gensim.models.keyedvectors.Vocab at 0x284ea81e9d0>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x284ea81ea30>,
#  'heelwide': <gensim.models.keyedvectors.Vocab at 0x284ea81ea90>,
#  'snake': <gensim.models.keyedvectors.Vocab at 0x284ea81eaf0>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x284ea81eb50>,
#  'bagmock-snake': <gensim.models.keyedvectors.Vocab at 0x284ea81ebb0>,
#  'stylesnaffle': <gensim.models.keyedvectors.Vocab at 0x284ea81ec10>,
#  'solemoulded': <gensim.models.keyedvectors.Vocab at 0x284ea81ec70>,
#  'solewide': <gensim.models.keyedvectors.Vocab at 0x284ea81ecd0>,
#  'falconi': <gensim.models.keyedvectors.Vocab at 0x284ea81ed30>,
#  'fragrances': <gensim.models.keyedvectors.Vocab at 0x284ea81ed90>,
#  'trainersall-over': <gensim.models.keyedvectors.Vocab at 0x284ea81edf0>,
#  'shermantwo': <gensim.models.keyedvectors.Vocab at 0x284ea81ee50>,
#  'stylebar': <gensim.models.keyedvectors.Vocab at 0x284ea81eeb0>,
#  'detailapron': <gensim.models.keyedvectors.Vocab at 0x284ea81ef10>,
#  'toeflat': <gensim.models.keyedvectors.Vocab at 0x284ea81ef70>,
#  'slidder': <gensim.models.keyedvectors.Vocab at 0x284ea81efd0>,
#  'prince': <gensim.models.keyedvectors.Vocab at 0x284ea821070>,
#  'wales': <gensim.models.keyedvectors.Vocab at 0x284ea8210d0>,
#  'millennial': <gensim.models.keyedvectors.Vocab at 0x284ea821130>,
#  'slipperwide-cut': <gensim.models.keyedvectors.Vocab at 0x284ea821190>,
#  'strapcheck': <gensim.models.keyedvectors.Vocab at 0x284ea8211f0>,
#  'styleopen': <gensim.models.keyedvectors.Vocab at 0x284ea821250>,
#  'uppermatte': <gensim.models.keyedvectors.Vocab at 0x284ea8212b0>,
#  'finishsole': <gensim.models.keyedvectors.Vocab at 0x284ea821310>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x284ea821370>,
#  'trim': <gensim.models.keyedvectors.Vocab at 0x284ea8213d0>,
#  'mules': <gensim.models.keyedvectors.Vocab at 0x284ea821430>,
#  'backgold-tone': <gensim.models.keyedvectors.Vocab at 0x284ea821490>,
#  'snafflealmond': <gensim.models.keyedvectors.Vocab at 0x284ea8214f0>,
#  'toestacked': <gensim.models.keyedvectors.Vocab at 0x284ea821550>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x284ea8215b0>,
#  'penny': <gensim.models.keyedvectors.Vocab at 0x284ea821610>,
#  'stylepenny': <gensim.models.keyedvectors.Vocab at 0x284ea821670>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x284ea8216d0>,
#  'stacked': <gensim.models.keyedvectors.Vocab at 0x284ea821730>,
#  'joele': <gensim.models.keyedvectors.Vocab at 0x284ea821790>,
#  'unboxing': <gensim.models.keyedvectors.Vocab at 0x284ea8217f0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x284ea821850>,
#  'considerable': <gensim.models.keyedvectors.Vocab at 0x284ea8218b0>,
#  'fasteninground': <gensim.models.keyedvectors.Vocab at 0x284ea821910>,
#  'panels': <gensim.models.keyedvectors.Vocab at 0x284ea821970>,
#  'inner': <gensim.models.keyedvectors.Vocab at 0x284ea8219d0>,
#  'bagpull': <gensim.models.keyedvectors.Vocab at 0x284ea821a30>,
#  'entrybrogue': <gensim.models.keyedvectors.Vocab at 0x284ea821a90>,
#  'nike': <gensim.models.keyedvectors.Vocab at 0x284ea821af0>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x284ea821b50>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x284ea821bb0>,
#  '2090': <gensim.models.keyedvectors.Vocab at 0x284ea821c10>,
#  'cl': <gensim.models.keyedvectors.Vocab at 0x284ea821c70>,
#  'white/turquoise': <gensim.models.keyedvectors.Vocab at 0x284ea821cd0>,
#  'innovative': <gensim.models.keyedvectors.Vocab at 0x284ea821d30>,
#  'sportswear': <gensim.models.keyedvectors.Vocab at 0x284ea821d90>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x284ea821df0>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x284ea821e50>,
#  'best-selling': <gensim.models.keyedvectors.Vocab at 0x284ea821eb0>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x284ea821f10>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x284ea821f70>,
#  '1s': <gensim.models.keyedvectors.Vocab at 0x284ea821fd0>,
#  'super-cushioned': <gensim.models.keyedvectors.Vocab at 0x284ea822070>,
#  'vapormax': <gensim.models.keyedvectors.Vocab at 0x284ea8220d0>,
#  'browse': <gensim.models.keyedvectors.Vocab at 0x284ea822130>,
#  'techy': <gensim.models.keyedvectors.Vocab at 0x284ea822190>,
#  'joggers': <gensim.models.keyedvectors.Vocab at 0x284ea8221f0>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x284ea822250>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x284ea8222b0>,
#  'football': <gensim.models.keyedvectors.Vocab at 0x284ea822310>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x284ea822370>,
#  'sports': <gensim.models.keyedvectors.Vocab at 0x284ea8223d0>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x284ea822430>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x284ea822490>,
#  'bands': <gensim.models.keyedvectors.Vocab at 0x284ea8224f0>,
#  'fitness': <gensim.models.keyedvectors.Vocab at 0x284ea822550>,
#  'aids': <gensim.models.keyedvectors.Vocab at 0x284ea8225b0>,
#  'sb': <gensim.models.keyedvectors.Vocab at 0x284ea822610>,
#  'nails': <gensim.models.keyedvectors.Vocab at 0x284ea822670>,
#  'hoodies': <gensim.models.keyedvectors.Vocab at 0x284ea8226d0>,
#  'chinos': <gensim.models.keyedvectors.Vocab at 0x284ea822730>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x284ea822790>,
#  'mid-cut': <gensim.models.keyedvectors.Vocab at 0x284ea8227f0>,
#  'swoosh': <gensim.models.keyedvectors.Vocab at 0x284ea822850>,
#  'sides': <gensim.models.keyedvectors.Vocab at 0x284ea8228b0>,
#  'foam': <gensim.models.keyedvectors.Vocab at 0x284ea822910>,
#  'cushioningnike': <gensim.models.keyedvectors.Vocab at 0x284ea822970>,
#  'units': <gensim.models.keyedvectors.Vocab at 0x284ea8229d0>,
# ...
#  'light': <gensim.models.keyedvectors.Vocab at 0x284ea824070>,
#  'vibes': <gensim.models.keyedvectors.Vocab at 0x284ea8240d0>,
#  'cuffchunky': <gensim.models.keyedvectors.Vocab at 0x284ea824130>,
#  'monk': <gensim.models.keyedvectors.Vocab at 0x284ea824190>,
#  'suitable': <gensim.models.keyedvectors.Vocab at 0x284ea8241f0>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x284ea824250>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x284ea8242b0>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x284ea824310>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x284ea824370>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x284ea8243d0>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x284ea824430>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x284ea824490>,
#  'upperit': <gensim.models.keyedvectors.Vocab at 0x284ea8244f0>,
#  'deallining': <gensim.models.keyedvectors.Vocab at 0x284ea824550>,
#  'soulif': <gensim.models.keyedvectors.Vocab at 0x284ea8245b0>,
#  'cuffsilver-tone': <gensim.models.keyedvectors.Vocab at 0x284ea824610>,
#  'detailchunky': <gensim.models.keyedvectors.Vocab at 0x284ea824670>,
#  'gold': <gensim.models.keyedvectors.Vocab at 0x284ea8246d0>,
#  'cuffpatent': <gensim.models.keyedvectors.Vocab at 0x284ea824730>,
#  'trims': <gensim.models.keyedvectors.Vocab at 0x284ea824790>,
#  'knitted': <gensim.models.keyedvectors.Vocab at 0x284ea8247f0>,
#  'wrapped': <gensim.models.keyedvectors.Vocab at 0x284ea824850>,
#  'shaped': <gensim.models.keyedvectors.Vocab at 0x284ea8248b0>,
#  'arroyo': <gensim.models.keyedvectors.Vocab at 0x284ea824910>,
#  'runner': <gensim.models.keyedvectors.Vocab at 0x284ea824970>,
#  'brandingremovable': <gensim.models.keyedvectors.Vocab at 0x284ea8249d0>,
#  'ortholite': <gensim.models.keyedvectors.Vocab at 0x284ea824a30>,
#  'eco': <gensim.models.keyedvectors.Vocab at 0x284ea824a90>,
#  'x40': <gensim.models.keyedvectors.Vocab at 0x284ea824af0>,
#  'overlayssole': <gensim.models.keyedvectors.Vocab at 0x284ea824b50>,
#  '55': <gensim.models.keyedvectors.Vocab at 0x284ea824bb0>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x284ea824c10>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x284ea824c70>,
#  'streetsome': <gensim.models.keyedvectors.Vocab at 0x284ea824cd0>,
#  'occasions': <gensim.models.keyedvectors.Vocab at 0x284ea824d30>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x284ea824d90>,
#  'smarter': <gensim.models.keyedvectors.Vocab at 0x284ea824df0>,
#  'shoeclassic': <gensim.models.keyedvectors.Vocab at 0x284ea824e50>,
#  'fasteningalmond': <gensim.models.keyedvectors.Vocab at 0x284ea824eb0>,
#  'toeslim': <gensim.models.keyedvectors.Vocab at 0x284ea824f10>,
#  'augusto': <gensim.models.keyedvectors.Vocab at 0x284ea824f70>,
#  'hi': <gensim.models.keyedvectors.Vocab at 0x284ea824fd0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x284ea827070>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x284ea8270d0>,
#  'archives': <gensim.models.keyedvectors.Vocab at 0x284ea827130>,
#  'high-top': <gensim.models.keyedvectors.Vocab at 0x284ea827190>,
#  'river': <gensim.models.keyedvectors.Vocab at 0x284ea8271f0>,
#  'island': <gensim.models.keyedvectors.Vocab at 0x284ea827250>,
#  'oxfords': <gensim.models.keyedvectors.Vocab at 0x284ea8272b0>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x284ea827310>,
#  'high-street': <gensim.models.keyedvectors.Vocab at 0x284ea827370>,
#  'favourite': <gensim.models.keyedvectors.Vocab at 0x284ea8273d0>,
#  'decades': <gensim.models.keyedvectors.Vocab at 0x284ea827430>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x284ea827490>,
#  'adding': <gensim.models.keyedvectors.Vocab at 0x284ea8274f0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x284ea827550>,
#  'looks': <gensim.models.keyedvectors.Vocab at 0x284ea8275b0>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x284ea827610>,
#  'ri': <gensim.models.keyedvectors.Vocab at 0x284ea827670>,
#  'twist': <gensim.models.keyedvectors.Vocab at 0x284ea8276d0>,
#  'everyday': <gensim.models.keyedvectors.Vocab at 0x284ea827730>,
#  'sharp': <gensim.models.keyedvectors.Vocab at 0x284ea827790>,
#  'tailoring': <gensim.models.keyedvectors.Vocab at 0x284ea8277f0>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x284ea827850>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x284ea8278b0>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x284ea827910>,
#  'frontpoint': <gensim.models.keyedvectors.Vocab at 0x284ea827970>,
#  'stylegold-tone': <gensim.models.keyedvectors.Vocab at 0x284ea8279d0>,
#  'snaffleapron': <gensim.models.keyedvectors.Vocab at 0x284ea827a30>,
#  'fasteningwoven': <gensim.models.keyedvectors.Vocab at 0x284ea827a90>,
#  'panel': <gensim.models.keyedvectors.Vocab at 0x284ea827af0>,
#  'frontround': <gensim.models.keyedvectors.Vocab at 0x284ea827b50>,
#  'ankle': <gensim.models.keyedvectors.Vocab at 0x284ea827bb0>,
#  'frontzip-side': <gensim.models.keyedvectors.Vocab at 0x284ea827c10>,
#  'soultwo': <gensim.models.keyedvectors.Vocab at 0x284ea827c70>,
#  'bagplain': <gensim.models.keyedvectors.Vocab at 0x284ea827cd0>,
#  'entryslip-on': <gensim.models.keyedvectors.Vocab at 0x284ea827d30>,
#  'insertsalmond': <gensim.models.keyedvectors.Vocab at 0x284ea827d90>,
#  'lightly': <gensim.models.keyedvectors.Vocab at 0x284ea827df0>,
#  'designunboxing': <gensim.models.keyedvectors.Vocab at 0x284ea827e50>,
#  'considerablelow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea827eb0>,
#  'frontmoulded': <gensim.models.keyedvectors.Vocab at 0x284ea827f10>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x284ea827f70>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x284ea827fd0>,
#  'plimsoll': <gensim.models.keyedvectors.Vocab at 0x284ea828070>,
#  'plain': <gensim.models.keyedvectors.Vocab at 0x284ea8280d0>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x284ea828130>,
#  'stretching': <gensim.models.keyedvectors.Vocab at 0x284ea828190>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x284ea8281f0>,
#  'draw': <gensim.models.keyedvectors.Vocab at 0x284ea828250>,
#  'inspiration': <gensim.models.keyedvectors.Vocab at 0x284ea8282b0>,
#  'retro': <gensim.models.keyedvectors.Vocab at 0x284ea828310>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x284ea828370>,
#  'vintage': <gensim.models.keyedvectors.Vocab at 0x284ea8283d0>,
#  'inspired': <gensim.models.keyedvectors.Vocab at 0x284ea828430>,
#  'incorporates': <gensim.models.keyedvectors.Vocab at 0x284ea828490>,
#  'brands': <gensim.models.keyedvectors.Vocab at 0x284ea8284f0>,
#  'reshuffle': <gensim.models.keyedvectors.Vocab at 0x284ea828550>,
#  'trainer': <gensim.models.keyedvectors.Vocab at 0x284ea8285b0>,
#  'rotationlace-up': <gensim.models.keyedvectors.Vocab at 0x284ea828610>,
#  'fasteningbranded': <gensim.models.keyedvectors.Vocab at 0x284ea828670>,
#  'cuffpadded': <gensim.models.keyedvectors.Vocab at 0x284ea8286d0>,
#  'comfortslim': <gensim.models.keyedvectors.Vocab at 0x284ea828730>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x284ea828790>,
#  'finishlining': <gensim.models.keyedvectors.Vocab at 0x284ea8287f0>,
#  'dad': <gensim.models.keyedvectors.Vocab at 0x284ea828850>,
#  'collectionif': <gensim.models.keyedvectors.Vocab at 0x284ea8288b0>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x284ea828910>,
#  'pu': <gensim.models.keyedvectors.Vocab at 0x284ea828970>,
#  'joins': <gensim.models.keyedvectors.Vocab at 0x284ea8289d0>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x284ea828a30>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x284ea828a90>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x284ea828af0>,
#  'showcasing': <gensim.models.keyedvectors.Vocab at 0x284ea828b50>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x284ea828bb0>,
#  'upcoming': <gensim.models.keyedvectors.Vocab at 0x284ea828c10>,
#  'staying': <gensim.models.keyedvectors.Vocab at 0x284ea828c70>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x284ea828cd0>,
#  'graphic': <gensim.models.keyedvectors.Vocab at 0x284ea828d30>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x284ea828d90>,
#  'rebel': <gensim.models.keyedvectors.Vocab at 0x284ea828df0>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x284ea828e50>,
#  'effortless': <gensim.models.keyedvectors.Vocab at 0x284ea828eb0>,
#  'streettwo': <gensim.models.keyedvectors.Vocab at 0x284ea828f10>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x284ea828f70>,
#  'photographers': <gensim.models.keyedvectors.Vocab at 0x284ea828fd0>,
#  'homelow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea82a070>,
#  'heelchunky': <gensim.models.keyedvectors.Vocab at 0x284ea82a0d0>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x284ea82a130>,
#  'athomewithasos': <gensim.models.keyedvectors.Vocab at 0x284ea82a190>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x284ea82a1f0>,
#  'scene': <gensim.models.keyedvectors.Vocab at 0x284ea82a250>,
#  'london-based': <gensim.models.keyedvectors.Vocab at 0x284ea82a2b0>,
#  'brings': <gensim.models.keyedvectors.Vocab at 0x284ea82a310>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x284ea82a370>,
#  'minimalism': <gensim.models.keyedvectors.Vocab at 0x284ea82a3d0>,
#  'relaxed': <gensim.models.keyedvectors.Vocab at 0x284ea82a430>,
#  'urban': <gensim.models.keyedvectors.Vocab at 0x284ea82a490>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x284ea82a4f0>,
#  'colour': <gensim.models.keyedvectors.Vocab at 0x284ea82a550>,
#  'palette': <gensim.models.keyedvectors.Vocab at 0x284ea82a5b0>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x284ea82a610>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x284ea82a670>,
#  'colour-block': <gensim.models.keyedvectors.Vocab at 0x284ea82a6d0>,
#  'oversized': <gensim.models.keyedvectors.Vocab at 0x284ea82a730>,
#  'apparel': <gensim.models.keyedvectors.Vocab at 0x284ea82a790>,
#  'laid-back': <gensim.models.keyedvectors.Vocab at 0x284ea82a7f0>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x284ea82a850>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x284ea82a8b0>,
#  'peep': <gensim.models.keyedvectors.Vocab at 0x284ea82a910>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x284ea82a970>,
#  'embroidered': <gensim.models.keyedvectors.Vocab at 0x284ea82a9d0>,
#  'logos': <gensim.models.keyedvectors.Vocab at 0x284ea82aa30>,
#  'teddy': <gensim.models.keyedvectors.Vocab at 0x284ea82aa90>,
#  'textures': <gensim.models.keyedvectors.Vocab at 0x284ea82aaf0>,
#  'prints': <gensim.models.keyedvectors.Vocab at 0x284ea82ab50>,
#  'featuring': <gensim.models.keyedvectors.Vocab at 0x284ea82abb0>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x284ea82ac10>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x284ea82ac70>,
#  'weatherv-shaped': <gensim.models.keyedvectors.Vocab at 0x284ea82acd0>,
#  'toe-post': <gensim.models.keyedvectors.Vocab at 0x284ea82ad30>,
#  'super-smooth': <gensim.models.keyedvectors.Vocab at 0x284ea82ad90>,
#  'daybreak-type': <gensim.models.keyedvectors.Vocab at 0x284ea82adf0>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x284ea82ae50>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x284ea82aeb0>,
#  'excluded': <gensim.models.keyedvectors.Vocab at 0x284ea82af10>,
#  'promopart': <gensim.models.keyedvectors.Vocab at 0x284ea82af70>,
#  'glitter': <gensim.models.keyedvectors.Vocab at 0x284ea82afd0>,
#  'crater': <gensim.models.keyedvectors.Vocab at 0x284ea82d070>,
#  'avalon': <gensim.models.keyedvectors.Vocab at 0x284ea82d0d0>,
#  'toffee': <gensim.models.keyedvectors.Vocab at 0x284ea82d130>,
#  'insertlogo': <gensim.models.keyedvectors.Vocab at 0x284ea82d190>,
#  'stylechain': <gensim.models.keyedvectors.Vocab at 0x284ea82d1f0>,
#  'detailingapron': <gensim.models.keyedvectors.Vocab at 0x284ea82d250>,
#  'demos': <gensim.models.keyedvectors.Vocab at 0x284ea82d2b0>,
#  '98': <gensim.models.keyedvectors.Vocab at 0x284ea82d310>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x284ea82d370>,
#  'chunkier': <gensim.models.keyedvectors.Vocab at 0x284ea82d3d0>,
#  'entryzip': <gensim.models.keyedvectors.Vocab at 0x284ea82d430>,
#  'dune': <gensim.models.keyedvectors.Vocab at 0x284ea82d490>,
#  'opened': <gensim.models.keyedvectors.Vocab at 0x284ea82d4f0>,
#  '1993': <gensim.models.keyedvectors.Vocab at 0x284ea82d550>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x284ea82d5b0>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x284ea82d610>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x284ea82d670>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x284ea82d6d0>,
#  'specialists': <gensim.models.keyedvectors.Vocab at 0x284ea82d730>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x284ea82d790>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x284ea82d7f0>,
#  'defining': <gensim.models.keyedvectors.Vocab at 0x284ea82d850>,
#  'attitude': <gensim.models.keyedvectors.Vocab at 0x284ea82d8b0>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x284ea82d910>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x284ea82d970>,
#  'dedicated': <gensim.models.keyedvectors.Vocab at 0x284ea82d9d0>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x284ea82da30>,
#  'wingcap': <gensim.models.keyedvectors.Vocab at 0x284ea82da90>,
#  'derbies': <gensim.models.keyedvectors.Vocab at 0x284ea82daf0>,
#  'cuffs': <gensim.models.keyedvectors.Vocab at 0x284ea82db50>,
#  'panelschunky': <gensim.models.keyedvectors.Vocab at 0x284ea82dbb0>,
#  '70': <gensim.models.keyedvectors.Vocab at 0x284ea82dc10>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x284ea82dc70>,
#  'toetassel': <gensim.models.keyedvectors.Vocab at 0x284ea82dcd0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x284ea82dd30>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x284ea82dd90>,
#  'designcontrast': <gensim.models.keyedvectors.Vocab at 0x284ea82ddf0>,
#  'uppertextured': <gensim.models.keyedvectors.Vocab at 0x284ea82de50>,
#  'mixed': <gensim.models.keyedvectors.Vocab at 0x284ea82deb0>,
#  'breathability': <gensim.models.keyedvectors.Vocab at 0x284ea82df10>,
#  'balsam': <gensim.models.keyedvectors.Vocab at 0x284ea82df70>,
#  'seasonslip-on': <gensim.models.keyedvectors.Vocab at 0x284ea82dfd0>,
#  '33': <gensim.models.keyedvectors.Vocab at 0x284ea82e070>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x284ea82e0d0>,
#  'designslip-on': <gensim.models.keyedvectors.Vocab at 0x284ea82e130>,
#  'effectscamouflage': <gensim.models.keyedvectors.Vocab at 0x284ea82e190>,
#  'ergonomic': <gensim.models.keyedvectors.Vocab at 0x284ea82e1f0>,
#  'footbedheel': <gensim.models.keyedvectors.Vocab at 0x284ea82e250>,
#  'cup': <gensim.models.keyedvectors.Vocab at 0x284ea82e2b0>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x284ea82e310>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x284ea82e370>,
#  'positionbloom': <gensim.models.keyedvectors.Vocab at 0x284ea82e3d0>,
#  'algae': <gensim.models.keyedvectors.Vocab at 0x284ea82e430>,
#  'insert': <gensim.models.keyedvectors.Vocab at 0x284ea82e490>,
#  'soulswitch': <gensim.models.keyedvectors.Vocab at 0x284ea82e4f0>,
#  'rotationpull': <gensim.models.keyedvectors.Vocab at 0x284ea82e550>,
#  'entrylow-profile': <gensim.models.keyedvectors.Vocab at 0x284ea82e5b0>,
#  'cuffcolour-block': <gensim.models.keyedvectors.Vocab at 0x284ea82e610>,
#  'midsoledurable': <gensim.models.keyedvectors.Vocab at 0x284ea82e670>,
#  'tommy': <gensim.models.keyedvectors.Vocab at 0x284ea82e6d0>,
#  'hilfiger': <gensim.models.keyedvectors.Vocab at 0x284ea82e730>,
#  'nautical': <gensim.models.keyedvectors.Vocab at 0x284ea82e790>,
#  'beach': <gensim.models.keyedvectors.Vocab at 0x284ea82e7f0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x284ea82e850>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x284ea82e8b0>,
#  'colour-blocking': <gensim.models.keyedvectors.Vocab at 0x284ea82e910>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x284ea82e970>,
#  'mistaking': <gensim.models.keyedvectors.Vocab at 0x284ea82e9d0>,
#  'flying': <gensim.models.keyedvectors.Vocab at 0x284ea82ea30>,
#  'flag': <gensim.models.keyedvectors.Vocab at 0x284ea82ea90>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x284ea82eaf0>,
#  '90s': <gensim.models.keyedvectors.Vocab at 0x284ea82eb50>,
#  'wardrobe-ready': <gensim.models.keyedvectors.Vocab at 0x284ea82ebb0>,
#  'swimwear': <gensim.models.keyedvectors.Vocab at 0x284ea82ec10>,
#  'pieces': <gensim.models.keyedvectors.Vocab at 0x284ea82ec70>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x284ea82ecd0>,
#  ...}
